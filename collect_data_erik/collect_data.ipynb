# %%
import pandas as pd
import time

# %%
import requests
import pandas as pd


# Funktion, um alle Revisionen zu sammeln
def fetch_revisions(title):
    url = "https://de.wikipedia.org/w/api.php"
    params = {
    "action": "query",
    "format": "json",
    "prop": "revisions",
    "titles": title,
    "rvlimit": "max",  # Maximale Anzahl Revisionen pro Anfrage
    "rvprop": "timestamp|size|user|tags|comment",  # Wir brauchen Zeitstempel und Größe der Revision
    "continue": ""
}
    all_revisions = []
    session = requests.Session()
    while True:
        response = session.get(url, params=params)
        data = response.json()
        
        pages = data.get("query", {}).get("pages", {})
        for page_id, page_data in pages.items():
            revisions = page_data.get("revisions", [])
            all_revisions.extend(revisions)
        
        # Weiter paginieren, falls mehr Ergebnisse vorhanden sind
        if "continue" in data:
            params.update(data["continue"])
        else:
            break
    
    return all_revisions

def save_wiki_revisions(article_title):
    # Daten holen
    revisions = fetch_revisions(article_title)

    revision_data = []  # Hier speichern wir alle Details
    
    for i in range(0, len(revisions)):
        
        if i == len(revisions)-1:
            prev_size = 0
        else:
            prev_size = revisions[i + 1].get("size", 0)
        curr_size = revisions[i].get("size", 0)
        timestamp = revisions[i]["timestamp"][:10]  # Nur das Datum (YYYY-MM-DD)
        
        # Revision Details speichern
        revision_data.append({
            "Date": revisions[i]["timestamp"][:10],
            "Time": revisions[i]["timestamp"],
            "User": revisions[i].get("user", "Unknown"),
            "Size": curr_size,
            "changes": (curr_size - prev_size),
            "Comment": revisions[i].get("comment", "No comment"),
            "Tags": ", ".join(revisions[i].get("tags", [])) if revisions[i].get("tags") else "None"
        })

    # Revision Details speichern
    revision_df = pd.DataFrame(revision_data)
    revision_df.to_csv(f"data/revisionen/{article_title}_revisions.csv", index=False)
    print(f"Alle Revisionen gespeichert in '{article_title}_revisions.csv'")

# %%
# Out:
#      Bild               Name  Lebensdaten Fraktion oder Gruppe (Partei)  \
# 0     NaN         Sanae Abdi         1986                           SPD
# 1     NaN      Valentin Abel         1991                           FDP
# 2     NaN       Knut Abraham         1966                 CDU/CSU (CDU)
# 3     NaN        Katja Adler         1974                           FDP
# 4     NaN  Stephanie Aeffner         1976                         Grüne
# ..    ...                ...          ...                           ...
# 728   NaN      Stefan Zierke         1970                           SPD
# 729   NaN    Jens Zimmermann         1981                           SPD
# 730   NaN  Nicolas Zippelius         1987                 CDU/CSU (CDU)
# 731   NaN        Armand Zorn         1988                           SPD
# 732   NaN      Katrin Zschau         1976                           SPD
#
#                        Land Listenplatz  \
# 0       Nordrhein-Westfalen    Platz 40
# 1         Baden-Württemberg    Platz 12
# 2               Brandenburg     Platz 4
# 3                    Hessen     Platz 6
# 4         Baden-Württemberg    Platz 15
# ..                      ...         ...
# 728             Brandenburg     Platz 3
# 729                  Hessen     Platz 7
# 730       Baden-Württemberg           –
# 731                  Hessen    Platz 23
# 732  Mecklenburg-Vorpommern     Platz 4
#
#                                   Wahlkreis Erststimmenanteil  \
# 0                                    Köln I            27,9 %
# 1               Schwäbisch Hall – Hohenlohe            11,7 %
# 2    Elbe-Elster – Oberspreewald-Lausitz II            16,2 %
# 3                                Hochtaunus            11,3 %
# 4                                 Pforzheim            12,7 %
# ..                                      ...               ...
# 728                    Uckermark – Barnim I            29,6 %
# 729                                Odenwald            32,3 %
# 730                          Karlsruhe-Land            30,4 %
# 731                             Frankfurt I            29,0 %
# 732          Rostock – Landkreis Rostock II            27,0 %
#
#                Beruflicher Hintergrund MdB seit Bemerkungen  \
# 0        Vertrags- und Finanzmanagerin     2021         NaN
# 1                         Betriebswirt     2021         NaN
# 2             Soldat, Jurist, Diplomat     2021         NaN
# 3                Verwaltungsfachwirtin     2021         NaN
# 4                     Sozialarbeiterin     2021         NaN
# ..                                 ...      ...         ...
# 728  Werkzeugmacher, Touristikfachwirt     2013         NaN
# 729                           Kaufmann     2013         NaN
# 730             Politikwissenschaftler     2021         NaN
# 731                Unternehmensberater     2021         NaN
# 732            Landesgeschäftsführerin     2021         NaN
#
#                                   link
# 0                     /wiki/Sanae_Abdi
# 1      /wiki/Valentin_Abel_(Politiker)
# 2                   /wiki/Knut_Abraham
# 3                    /wiki/Katja_Adler
# 4              /wiki/Stephanie_Aeffner
# ..                                 ...
# 728                /wiki/Stefan_Zierke
# 729  /wiki/Jens_Zimmermann_(Politiker)
# 730            /wiki/Nicolas_Zippelius
# 731                  /wiki/Armand_Zorn
# 732                /wiki/Katrin_Zschau
#
# [733 rows x 12 columns]

# %%
df = pd.read_csv('data/colect links/austrian_25.csv')
for link in df['link']:
    link = link.split('/')[-1]
    save_wiki_revisions(link)
    time.sleep(1)
# Out:
# Alle Revisionen gespeichert in 'Niko_Alm_revisions.csv'
# Alle Revisionen gespeichert in 'Werner_Amon_revisions.csv'
# Alle Revisionen gespeichert in 'Erwin_Angerer_revisions.csv'
# Alle Revisionen gespeichert in 'Konrad_Antoni_revisions.csv'
# Alle Revisionen gespeichert in 'Ayg%C3%BCl_Ber%C3%AEvan_Aslan_revisions.csv'
# Alle Revisionen gespeichert in 'Gertrude_Aubauer_revisions.csv'
# Alle Revisionen gespeichert in 'Jakob_Auer_(Politiker)_revisions.csv'
# Alle Revisionen gespeichert in 'Walter_Bacher_(Politiker)_revisions.csv'
# Alle Revisionen gespeichert in 'Petra_Bayr_revisions.csv'
# Alle Revisionen gespeichert in 'Ruth_Becher_revisions.csv'
# Alle Revisionen gespeichert in 'Dagmar_Belakowitsch-Jenewein_revisions.csv'
# Alle Revisionen gespeichert in 'Nikolaus_Berlakovich_revisions.csv'
# Alle Revisionen gespeichert in 'Michael_Bernhard_(Politiker)_revisions.csv'
# Alle Revisionen gespeichert in 'Reinhard_Eugen_B%C3%B6sch_revisions.csv'
# Alle Revisionen gespeichert in 'Dieter_Brosz_revisions.csv'
# Alle Revisionen gespeichert in 'Hermann_Br%C3%BCckl_revisions.csv'
# Alle Revisionen gespeichert in 'Christiane_Brunner_(Politikerin,_1976)_revisions.csv'
# Alle Revisionen gespeichert in 'Harry_Rudolf_Buchmayr_revisions.csv'
# Alle Revisionen gespeichert in 'Doris_Bures_revisions.csv'
# Alle Revisionen gespeichert in 'Josef_Cap_revisions.csv'
# Alle Revisionen gespeichert in 'Norbert_Darabos_revisions.csv'
# Alle Revisionen gespeichert in 'Gernot_Darmann_revisions.csv'
# Alle Revisionen gespeichert in 'Gerhard_Deimek_revisions.csv'
# Alle Revisionen gespeichert in 'Martina_Diesner-Wais_revisions.csv'
# Alle Revisionen gespeichert in 'Waltraud_Dietrich_revisions.csv'
# Alle Revisionen gespeichert in 'Karin_Doppelbauer_revisions.csv'
# Alle Revisionen gespeichert in 'Rupert_Doppler_revisions.csv'
# Alle Revisionen gespeichert in 'Claudia_Durchschlag_revisions.csv'
# Alle Revisionen gespeichert in 'Cornelia_Ecker_revisions.csv'
# Alle Revisionen gespeichert in 'Michael_Ehmann_revisions.csv'
# Alle Revisionen gespeichert in 'Asdin_El_Habbassi_revisions.csv'
# Alle Revisionen gespeichert in 'Rouven_Ertlschweiger_revisions.csv'
# Alle Revisionen gespeichert in 'Franz_E%C3%9Fl_revisions.csv'
# Alle Revisionen gespeichert in 'Werner_Faymann_revisions.csv'
# Alle Revisionen gespeichert in 'Hannes_Fazekas_revisions.csv'
# Alle Revisionen gespeichert in 'Klaus_Uwe_Feichtinger_revisions.csv'
# Alle Revisionen gespeichert in 'Maria_Theresia_Fekter_revisions.csv'
# Alle Revisionen gespeichert in 'Angela_Fichtinger_revisions.csv'
# Alle Revisionen gespeichert in 'Marcus_Franz_(Politiker,_1963)_revisions.csv'
# Alle Revisionen gespeichert in 'Hubert_Fuchs_revisions.csv'
# Alle Revisionen gespeichert in 'Hermann_Gahr_revisions.csv'
# Alle Revisionen gespeichert in 'Claudia_Gamon_revisions.csv'
# Alle Revisionen gespeichert in 'Wolfgang_Gerstl_revisions.csv'
# Alle Revisionen gespeichert in 'Andrea_Gessl-Ranftl_revisions.csv'
# Alle Revisionen gespeichert in 'Eva_Glawischnig-Piesczek_revisions.csv'
# Alle Revisionen gespeichert in 'Karin_Greiner_revisions.csv'
# Alle Revisionen gespeichert in 'Fritz_Grillitsch_(Politiker,_1959)_revisions.csv'
# Alle Revisionen gespeichert in 'Werner_Groi%C3%9F_revisions.csv'
# Alle Revisionen gespeichert in 'Elisabeth_Grossmann_revisions.csv'
# Alle Revisionen gespeichert in 'Marianne_Gusenbauer-J%C3%A4ger_revisions.csv'
# Alle Revisionen gespeichert in 'Rainer_Hable_revisions.csv'
# Alle Revisionen gespeichert in 'Heinz-Peter_Hackl_revisions.csv'
# Alle Revisionen gespeichert in 'Christian_Hafenecker_revisions.csv'
# Alle Revisionen gespeichert in 'Christoph_Hagen_revisions.csv'
# Alle Revisionen gespeichert in 'Roman_Haider_revisions.csv'
# Alle Revisionen gespeichert in 'Elisabeth_Hakel_revisions.csv'
# Alle Revisionen gespeichert in 'Michael_Hammer_(Politiker)_revisions.csv'
# Alle Revisionen gespeichert in 'Andreas_Hanger_revisions.csv'
# Alle Revisionen gespeichert in 'Peter_Haubner_revisions.csv'
# Alle Revisionen gespeichert in 'Gerald_Hauser_revisions.csv'
# Alle Revisionen gespeichert in 'Johann_Hechtl_revisions.csv'
# Alle Revisionen gespeichert in 'Gabriele_Heinisch-Hosek_revisions.csv'
# Alle Revisionen gespeichert in 'Anton_Heinzl_revisions.csv'
# Alle Revisionen gespeichert in 'Johann_Hell_revisions.csv'
# Alle Revisionen gespeichert in 'Eva-Maria_Himmelbauer_revisions.csv'
# Alle Revisionen gespeichert in 'Christian_H%C3%B6bart_revisions.csv'
# Alle Revisionen gespeichert in 'Norbert_Hofer_revisions.csv'
# Alle Revisionen gespeichert in 'Johann_H%C3%B6finger_revisions.csv'
# Alle Revisionen gespeichert in 'Manfred_Hofinger_revisions.csv'
# Alle Revisionen gespeichert in 'Daniela_Holzinger-Vogtenhuber_revisions.csv'
# Alle Revisionen gespeichert in 'Franz-Joseph_Huainigg_revisions.csv'
# Alle Revisionen gespeichert in 'Johannes_H%C3%BCbner_(Politiker)_revisions.csv'
# Alle Revisionen gespeichert in 'Rudolf_Hundstorfer_revisions.csv'
# Alle Revisionen gespeichert in 'Brigitte_Jank_revisions.csv'
# Alle Revisionen gespeichert in 'Harald_Jannach_revisions.csv'
# Alle Revisionen gespeichert in 'Helene_Jarmer_revisions.csv'
# Alle Revisionen gespeichert in 'Johannes_Jarolim_revisions.csv'
# Alle Revisionen gespeichert in 'Beatrix_Karl_revisions.csv'
# Alle Revisionen gespeichert in 'Andreas_Karlsb%C3%B6ck_revisions.csv'
# Alle Revisionen gespeichert in 'Axel_Kassegger_revisions.csv'
# Alle Revisionen gespeichert in 'Wolfgang_Katzian_revisions.csv'
# Alle Revisionen gespeichert in 'Dietmar_Keck_revisions.csv'
# Alle Revisionen gespeichert in 'Herbert_Kickl_revisions.csv'
# Alle Revisionen gespeichert in 'Franz_Kirchgatterer_revisions.csv'
# Alle Revisionen gespeichert in 'Anneliese_Kitzm%C3%BCller_revisions.csv'
# Alle Revisionen gespeichert in 'Wolfgang_Klinger_(Politiker)_revisions.csv'
# Alle Revisionen gespeichert in 'Gerald_Klug_revisions.csv'
# Alle Revisionen gespeichert in 'Wolfgang_Knes_revisions.csv'
# Alle Revisionen gespeichert in 'Matthias_K%C3%B6chl_revisions.csv'
# Alle Revisionen gespeichert in 'Werner_Kogler_revisions.csv'
# Alle Revisionen gespeichert in 'Ulrike_K%C3%B6nigsberger-Ludwig_revisions.csv'
# Alle Revisionen gespeichert in 'Karlheinz_Kopf_revisions.csv'
# Alle Revisionen gespeichert in 'Alev_Korun_revisions.csv'
# Alle Revisionen gespeichert in 'Kai_Jan_Krainer_revisions.csv'
# Alle Revisionen gespeichert in 'Hermann_Krist_revisions.csv'
# Alle Revisionen gespeichert in 'Katharina_Kucharowits_revisions.csv'
# Alle Revisionen gespeichert in 'Philip_Kucher_revisions.csv'
# Alle Revisionen gespeichert in 'G%C3%BCnther_Kumpitsch_revisions.csv'
# Alle Revisionen gespeichert in 'Mario_Kunasek_revisions.csv'
# Alle Revisionen gespeichert in 'Andrea_Kuntzl_revisions.csv'
# Alle Revisionen gespeichert in 'Sebastian_Kurz_revisions.csv'
# Alle Revisionen gespeichert in 'Hubert_Kuzdas_revisions.csv'
# Alle Revisionen gespeichert in 'David_Lasar_revisions.csv'
# Alle Revisionen gespeichert in 'Christian_Lausch_revisions.csv'
# Alle Revisionen gespeichert in 'Josef_Lettenbichler_revisions.csv'
# Alle Revisionen gespeichert in 'Ruperta_Lichtenecker_revisions.csv'
# Alle Revisionen gespeichert in 'Monika_Lindner_revisions.csv'
# Alle Revisionen gespeichert in 'Jessi_Lintl_revisions.csv'
# Alle Revisionen gespeichert in 'Hermann_Lipitsch_revisions.csv'
# Alle Revisionen gespeichert in 'Gerald_Loacker_revisions.csv'
# Alle Revisionen gespeichert in 'Reinhold_Lopatka_revisions.csv'
# Alle Revisionen gespeichert in 'Angela_Lueger_revisions.csv'
# Alle Revisionen gespeichert in 'Robert_Lugar_revisions.csv'
# Alle Revisionen gespeichert in 'Christoph_Matznetter_revisions.csv'
# Alle Revisionen gespeichert in 'Sigrid_Maurer_revisions.csv'
# Alle Revisionen gespeichert in 'Elmar_Mayer_(Politiker)_revisions.csv'
# Alle Revisionen gespeichert in 'Beate_Meinl-Reisinger_revisions.csv'
# Alle Revisionen gespeichert in 'Johanna_Mikl-Leitner_revisions.csv'
# Alle Revisionen gespeichert in 'Reinhold_Mitterlehner_revisions.csv'
# Alle Revisionen gespeichert in 'Angelika_Mlinar_revisions.csv'
# Alle Revisionen gespeichert in 'Wendelin_M%C3%B6lzer_revisions.csv'
# Alle Revisionen gespeichert in 'Gabriela_Moser_revisions.csv'
# Alle Revisionen gespeichert in 'Josef_Muchitsch_revisions.csv'
# Alle Revisionen gespeichert in 'Eva_M%C3%BCckstein_revisions.csv'
# Alle Revisionen gespeichert in 'Edith_M%C3%BChlberghuber_revisions.csv'
# Alle Revisionen gespeichert in 'Daniela_Musiol_revisions.csv'
# Alle Revisionen gespeichert in 'Christine_Muttonen_revisions.csv'
# Alle Revisionen gespeichert in 'Kathrin_Nachbaur_revisions.csv'
# Alle Revisionen gespeichert in 'Werner_Neubauer_(Politiker)_revisions.csv'
# Alle Revisionen gespeichert in 'Barbara_Neuroth_revisions.csv'
# Alle Revisionen gespeichert in 'Sabine_Oberhauser_revisions.csv'
# Alle Revisionen gespeichert in 'Gabriel_Obernosterer_revisions.csv'
# Alle Revisionen gespeichert in 'Friedrich_Ofenauer_revisions.csv'
# Alle Revisionen gespeichert in 'Karl_%C3%96llinger_revisions.csv'
# Alle Revisionen gespeichert in 'Andreas_Ottenschl%C3%A4ger_revisions.csv'
# Alle Revisionen gespeichert in 'Otto_Pendl_revisions.csv'
# Alle Revisionen gespeichert in 'Elisabeth_Pfurtscheller_revisions.csv'
# Alle Revisionen gespeichert in 'Peter_Pilz_revisions.csv'
# Alle Revisionen gespeichert in 'Wolfgang_Pirklhuber_revisions.csv'
# Alle Revisionen gespeichert in 'Rudolf_Plessl_revisions.csv'
# Alle Revisionen gespeichert in 'Elmar_Podgorschek_revisions.csv'
# Alle Revisionen gespeichert in 'Barbara_Prammer_revisions.csv'
# Alle Revisionen gespeichert in 'Erwin_Preiner_revisions.csv'
# Alle Revisionen gespeichert in 'Nikolaus_Prinz_revisions.csv'
# Alle Revisionen gespeichert in 'Johann_R%C3%A4dler_revisions.csv'
# Alle Revisionen gespeichert in 'Erwin_Rasinger_revisions.csv'
# Alle Revisionen gespeichert in 'Johannes_Rauch_(Politiker,_1971)_revisions.csv'
# Alle Revisionen gespeichert in 'Walter_Rauch_(Politiker,_1978)_revisions.csv'
# Alle Revisionen gespeichert in 'Josef_A._Riemer_revisions.csv'
# Alle Revisionen gespeichert in 'Barbara_Rosenkranz_revisions.csv'
# Alle Revisionen gespeichert in 'Walter_Rosenkranz_revisions.csv'
# Alle Revisionen gespeichert in 'Bruno_Rossmann_revisions.csv'
# Alle Revisionen gespeichert in 'Laura_Rudas_revisions.csv'
# Alle Revisionen gespeichert in 'J%C3%BCrgen_Schabh%C3%BCttl_revisions.csv'
# Alle Revisionen gespeichert in 'Birgit_Schatz_revisions.csv'
# Alle Revisionen gespeichert in 'Thomas_Schellenbacher_revisions.csv'
# Alle Revisionen gespeichert in 'Sepp_Schellhorn_revisions.csv'
# Alle Revisionen gespeichert in 'Martina_Schenk_revisions.csv'
# Alle Revisionen gespeichert in 'Nikolaus_Scherak_revisions.csv'
# Alle Revisionen gespeichert in 'Andreas_Schieder_revisions.csv'
# Alle Revisionen gespeichert in 'Carmen_Schimanek_revisions.csv'
# Alle Revisionen gespeichert in 'Dorothea_Schittenhelm_revisions.csv'
# Alle Revisionen gespeichert in 'Gerhard_Schmid_(Politiker,_1948)_revisions.csv'
# Alle Revisionen gespeichert in 'Julian_Schmid_(Politiker)_revisions.csv'
# Alle Revisionen gespeichert in 'Johannes_Schmuckenschlager_revisions.csv'
# Alle Revisionen gespeichert in 'Bernd_Sch%C3%B6negger_revisions.csv'
# Alle Revisionen gespeichert in 'Walter_Schopf_revisions.csv'
# Alle Revisionen gespeichert in 'Philipp_Schrangl_revisions.csv'
# Alle Revisionen gespeichert in 'Hermann_Schultes_revisions.csv'
# Alle Revisionen gespeichert in 'Judith_Schwentner_revisions.csv'
# Alle Revisionen gespeichert in 'Norbert_Sieber_revisions.csv'
# Alle Revisionen gespeichert in 'Johann_Singer_(Politiker)_revisions.csv'
# Alle Revisionen gespeichert in 'Erwin_Spindelberger_revisions.csv'
# Alle Revisionen gespeichert in 'Michael_Spindelegger_revisions.csv'
# Alle Revisionen gespeichert in 'Harald_Stefan_revisions.csv'
# Alle Revisionen gespeichert in 'Petra_Steger_revisions.csv'
# Alle Revisionen gespeichert in 'Michaela_Steinacker_revisions.csv'
# Alle Revisionen gespeichert in 'Leopold_Steinbichler_revisions.csv'
# Alle Revisionen gespeichert in 'Albert_Steinhauser_revisions.csv'
# Alle Revisionen gespeichert in 'Sonja_Ste%C3%9Fl_revisions.csv'
# Alle Revisionen gespeichert in 'Heinz-Christian_Strache_revisions.csv'
# Alle Revisionen gespeichert in 'Georg_Strasser_revisions.csv'
# Alle Revisionen gespeichert in 'Matthias_Strolz_revisions.csv'
# Alle Revisionen gespeichert in 'Frank_Stronach_revisions.csv'
# Alle Revisionen gespeichert in 'Gabriele_Tamandl_revisions.csv'
# Alle Revisionen gespeichert in 'Bernhard_Themessl_revisions.csv'
# Alle Revisionen gespeichert in 'Karlheinz_T%C3%B6chterle_revisions.csv'
# Alle Revisionen gespeichert in 'Harald_Troch_revisions.csv'
# Alle Revisionen gespeichert in 'Maximilian_Unterrainer_revisions.csv'
# Alle Revisionen gespeichert in 'Christoph_Vavrik_revisions.csv'
# Alle Revisionen gespeichert in 'Georg_Vetter_(Rechtsanwalt)_revisions.csv'
# Alle Revisionen gespeichert in 'Harald_Vilimsky_revisions.csv'
# Alle Revisionen gespeichert in 'Markus_Vogl_revisions.csv'
# Alle Revisionen gespeichert in 'Harald_Walser_revisions.csv'
# Alle Revisionen gespeichert in 'Ulla_Weigerstorfer_revisions.csv'
# Alle Revisionen gespeichert in 'Hannes_Weninger_(Politiker)_revisions.csv'
# Alle Revisionen gespeichert in 'Georg_Willi_revisions.csv'
# Alle Revisionen gespeichert in 'Rainer_Wimmer_(Politiker)_revisions.csv'
# Alle Revisionen gespeichert in 'Tanja_Windb%C3%BCchler-Souschill_revisions.csv'
# Alle Revisionen gespeichert in 'Susanne_Winter_revisions.csv'
# Alle Revisionen gespeichert in 'Angelika_Winzig_revisions.csv'
# Alle Revisionen gespeichert in 'Peter_Wittmann_revisions.csv'
# Alle Revisionen gespeichert in 'August_W%C3%B6ginger_revisions.csv'
# Alle Revisionen gespeichert in 'Gisela_Wurm_revisions.csv'
# Alle Revisionen gespeichert in 'Peter_Wurm_revisions.csv'
# Alle Revisionen gespeichert in 'Nurten_Yilmaz_revisions.csv'
# Alle Revisionen gespeichert in 'Andreas_Zakostelsky_revisions.csv'
# Alle Revisionen gespeichert in 'Wolfgang_Zanger_revisions.csv'
# Alle Revisionen gespeichert in 'Wolfgang_Zinggl_revisions.csv'
